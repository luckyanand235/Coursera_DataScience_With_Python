# %% [markdown]
# # Assignment 3

# %% [markdown]
# ### Que 1

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('C:\DataAnalytics\Energy Indicators.xls')

# %%
df
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# ..          ...                                                ...
# 277         NaN                       … denotes no data available.
# 278         NaN                                                NaN
# 279         NaN                                     Data Quality:
# 280         NaN  The data are compiled primarily from the annua...
# 281         NaN  For more information, visit http://unstats.un....
#
#                                             Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                     Environmental Indicators: Energy        NaN        NaN
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5'],
#       dtype='object')

# %%
df = df.drop(columns=['Unnamed: 0', 'Unnamed: 1'])

# %%
df
# Out:
#                                             Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                     Environmental Indicators: Energy        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2    Energy Supply and Renewable Electricity Produc...        NaN        NaN
# 3                                                  NaN        NaN        NaN
# 4                                                  NaN        NaN        NaN
# ..                                                 ...        ...        ...
# 277                                                NaN        NaN        NaN
# 278                                                NaN        NaN        NaN
# 279                                                NaN        NaN        NaN
# 280                                                NaN        NaN        NaN
# 281                                                NaN        NaN        NaN
#
#                      Unnamed: 5
# ...

# %%
df = df.rename(columns={'Unnamed: 2': 'Country', 'Unnamed: 3': 'Energy Supply', 'Unnamed: 4': 'Energy Supply per Capita', 'Unnamed: 5': '% Renewable'})

# %%
df
# Out:
#                                                Country Energy Supply  \
# 0                     Environmental Indicators: Energy           NaN
# 1                                                  NaN           NaN
# 2    Energy Supply and Renewable Electricity Produc...           NaN
# 3                                                  NaN           NaN
# 4                                                  NaN           NaN
# ..                                                 ...           ...
# 277                                                NaN           NaN
# 278                                                NaN           NaN
# 279                                                NaN           NaN
# 280                                                NaN           NaN
# 281                                                NaN           NaN
#
#     Energy Supply per Capita                 % Renewable
# 0                        NaN                         NaN
# ...

# %%
df['Energy Supply'] = df['Energy Supply']*1000000

# %%
df
# Out:
#                                                Country Energy Supply  \
# 0                     Environmental Indicators: Energy           NaN
# 1                                                  NaN           NaN
# 2    Energy Supply and Renewable Electricity Produc...           NaN
# 3                                                  NaN           NaN
# 4                                                  NaN           NaN
# ..                                                 ...           ...
# 277                                                NaN           NaN
# 278                                                NaN           NaN
# 279                                                NaN           NaN
# 280                                                NaN           NaN
# 281                                                NaN           NaN
#
#     Energy Supply per Capita                 % Renewable
# 0                        NaN                         NaN
# ...

# %%
data = df.copy()

# %%
data
# Out:
#                                                Country Energy Supply  \
# 0                     Environmental Indicators: Energy           NaN
# 1                                                  NaN           NaN
# 2    Energy Supply and Renewable Electricity Produc...           NaN
# 3                                                  NaN           NaN
# 4                                                  NaN           NaN
# ..                                                 ...           ...
# 277                                                NaN           NaN
# 278                                                NaN           NaN
# 279                                                NaN           NaN
# 280                                                NaN           NaN
# 281                                                NaN           NaN
#
#     Energy Supply per Capita                 % Renewable
# 0                        NaN                         NaN
# ...

# %%
data = data.set_index('Country')

# %%
data
# Out:
#                                                    Energy Supply  \
# Country
# Environmental Indicators: Energy                             NaN
# NaN                                                          NaN
# Energy Supply and Renewable Electricity Product...           NaN
# NaN                                                          NaN
# NaN                                                          NaN
# ...                                                          ...
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
#
#                                                    Energy Supply per Capita  \
# Country
# Environmental Indicators: Energy                                        NaN
# ...

# %%
data = data.T.rename(columns={"Republic of Korea": "South Korea", "United States of America": "United States", "United Kindom of Great Britain and Northern Ireland": "United Kingdom", "China, Hong Kong Special Administrative Region": "Hong Kong"})

# %%
data
# Out:
# Country                  Environmental Indicators: Energy  NaN  \
# Energy Supply                                         NaN  NaN
# Energy Supply per Capita                              NaN  NaN
# % Renewable                                           NaN  NaN
#
# Country                  Energy Supply and Renewable Electricity Production in 2013  \
# Energy Supply                                                           NaN
# Energy Supply per Capita                                                NaN
# % Renewable                                                             NaN
#
# Country                   NaN                         NaN  NaN  \
# Energy Supply             NaN                         NaN  NaN
# Energy Supply per Capita  NaN                         NaN  NaN
# % Renewable               NaN  Last update: December 2015  NaN
#
# Country                  Choose a country from the following drop-down list:  \
# ...

# %%
data
# Out:
# Country                  Environmental Indicators: Energy  NaN  \
# Energy Supply                                         NaN  NaN
# Energy Supply per Capita                              NaN  NaN
# % Renewable                                           NaN  NaN
#
# Country                  Energy Supply and Renewable Electricity Production in 2013  \
# Energy Supply                                                           NaN
# Energy Supply per Capita                                                NaN
# % Renewable                                                             NaN
#
# Country                   NaN                         NaN  NaN  \
# Energy Supply             NaN                         NaN  NaN
# Energy Supply per Capita  NaN                         NaN  NaN
# % Renewable               NaN  Last update: December 2015  NaN
#
# Country                  Choose a country from the following drop-down list:  \
# ...

# %%
data = data.T

# %%
from string import digits

# %%
for cols in ['Bolivia (Plurinational State of)', 'Switzerland32']:
    if '(' in cols:
        cols = cols.split('(')
        cols = cols[0]
        print(cols)
    
    if '0' or '1' or '2' or '3' or '4' or '5' or '6' or '7' or '8' or '9' in cols:
        cols = cols.re
# Out:
# Bolivia
# Bolivia
# Switzerland32

# %%
def answer_one():
    import numpy as np
    import pandas as pd
    energy = pd.read_excel('C:\DataAnalytics\Energy Indicators.xls', skipfooter=38, skiprows=17)
    col_name
    
    
    
    return energy

# %%
answer_one()
# Out:
#      Unnamed: 0                 Unnamed: 1                 Unnamed: 2  \
# 0           NaN                Afghanistan                Afghanistan
# 1           NaN                    Albania                    Albania
# 2           NaN                    Algeria                    Algeria
# 3           NaN             American Samoa             American Samoa
# 4           NaN                    Andorra                    Andorra
# ..          ...                        ...                        ...
# 222         NaN                   Viet Nam                   Viet Nam
# 223         NaN  Wallis and Futuna Islands  Wallis and Futuna Islands
# 224         NaN                      Yemen                      Yemen
# 225         NaN                     Zambia                     Zambia
# 226         NaN                   Zimbabwe                   Zimbabwe
#
#     Petajoules Gigajoules           %
# 0          321         10   78.669280
# 1          102         35  100.000000
# ...
